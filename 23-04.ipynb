# %%
# %pylab inline
import simdaq as s
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sis = s.LTI_System(T=10,fm=8000)
sis.filtroPasaBajoIdeal(frcor=1000)

# %%
sig1=s.Signal(t1=-5,t2=5,fm=8000)
sig1.pulse(pos=0,wid=1)

# %%
sig1.pinta()

# %%
sig2 = sis(sig1)
sig2.pinta(fxlim=(-10,10))

# %%
sig3=s.Signal(t1=-5,t2=5,fm=8000)
sig3.pulse(pos=0,wid=0.001)
sig4=sis(sig3)

# %%
sig3.pinta(xlim=(-0.003,0.003))

# %%
sig4.pinta(xlim=(-0.003,0.003))

# %%
sig5=s.Signal(t1=-5,t2=5,fm=8000)
sig5.step()
sig6=sis(sig3)

# %%
sig5.pinta(fxlim=(-4,4))

# %%
sig6.pinta()
