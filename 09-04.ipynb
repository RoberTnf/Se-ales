# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
N=512 #px
D=50 #mm

u = arange(-D/2, D/2, D/N)  #Objeto
v = arange(-D/2, D/2, D/N)
[uu,vv] = meshgrid(u,v)

x = arange(-D/2, D/2, D/N)  #Imagen
y = arange(-D/2, D/2, D/N)
[xx,yy] = meshgrid(x,y)
# Out:
# (2, 512, 512)

# %%
imshow(uu) #Valor coord X

# %%
imshow(vv)

# %%
pup = zeros((N,N))
pup[200:210,100:400]=1
pup[260:270,100:400]=1
imshow(pup)i

# %%
ima=np.fft.fft2(pup)

imshow(abs(ima))
colorbar()

# %%
#Pasamos a belios
imshow(20*log10(abs(ima)))
colorbar()
# Out:
# /usr/lib/python3.4/site-packages/IPython/kernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log10
#   from IPython.kernel.zmq import kernelapp as app
