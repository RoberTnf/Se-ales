# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ss = cos(2*pi*44000*arange(0,1,1/44100))
ss2 = cos(2*pi*44100*arange(0,1,1/44100))

# %%
plot(ss)
plot(ss2)
xlim(0,1500)
ylim(-1,1.1)
# Out:
# (-1, 1.1)
