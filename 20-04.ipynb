# %%
import simdaq
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
en = simdaq.Signal(t1=-5., t2=5., fm=44100)

# %%
plot(en.tiempo,en.ss)

# %%
en.gabor(fr=20)

# %%
en.pinta(titulo="Gabor 1KHz y sig=0.1s")

# %%
atr = simdaq.LTI_System(T=en.T,fm=en.fm)
atr.retraso_temporal(2)

# %%
sal = atr(en)

# %%
en.pinta()
sal.pinta()

# %%
plot(atr.tiempo,atr.h)  #Como no es un incremento diferencial, si no de 1/44100, la función llega a 44100.
